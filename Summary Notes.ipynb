# %%
# Summary Notes

#Array
#List
#Tuples
#Dictionary
#Dimensional Array
#Matrix
#Sets
#Maps

#Stack
# - Last In First Out

#Queue
# - First in First Out

#Dequeue
# - Adding and removing elements from either end
# ---collections.dequeue, append(val), appendleft(val), pop(), popleft()

#Hash Table
# - Dictionary

#Linked List
# - Each element contains a link to the next: Node0 -> Node1
#Doubly Linked List
# - Forward and Backwark links to next nodes: Node0 <=> Node1

#Binary Tree
# - Root node with 2 other nodes

#Search Tree
# - Smaller numbers on left of Root, Larger on Right

#In Order Tree Traversal
# - Left -> Root -> Right

#Pre Order Tree Traversal
# - Root -> Left -> Right

#Post Order Tree Traversal
# - Left -> Right -> Root

#Bubble Sort
# - Each pair of adjacent elements is compared -> swaped if not in order
#Merge Sort*
#Insertion Sort
#Shell Sort*
#Selection Sort
# - Go through each element and bring the smallest one to the front

#Linear Search
# - Every time is checked consecutively
#Interpolation/Binary Search*
# - For sorted items, check middle item

#Heaps

#Graph*
#Depth First Graph Traversal*
#Breadth First Graph Traversal*

#Resursion
#BackTracking*

#Big-0*

#General Python Notes*
